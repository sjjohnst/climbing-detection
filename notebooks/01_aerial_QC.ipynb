# %%
wms = "https://servicesmatriciels.mern.gouv.qc.ca/erdas-iws/ogc/wmts/Imagerie_Aeroportee_Forestiere_Historique?request=getcapabilities&service=wmts"
import leafmap

m = leafmap.Map(center=[46.8, -71.2], zoom=6)
m.add_wms_layer(wms, layers="mffpecofor:ecofor_2019", name="Ecofor 2019")
m
# Out:
# Map(center=[46.8, -71.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniforge3/envs/cliffDetection/lib/python3.13/site-packages/ipywidgets/widgets/widget.py in ?(self, *args, **kwargs)
#     224             ip = get_ipython()
#     225             if ip is None:
#     226                 self.log.warning("Exception in widget method %s: %s", method, e, exc_info=True)
#     227             else:
# --> 228                 ip.showtraceback()
#
# ~/miniforge3/envs/cliffDetection/lib/python3.13/site-packages/ipywidgets/widgets/widget.py in ?(self, msg)
#     769             if 'state' in data:
#     770                 state = data['state']
#     771                 if 'buffer_paths' in data:
#     772                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# ...

# %%
wmts = "https://servicesmatriciels.mern.gouv.qc.ca/erdas-iws/ogc/wmts/Imagerie_Aeroportee_Forestiere_Historique?request=getcapabilities&service=wmts"

# Acc
